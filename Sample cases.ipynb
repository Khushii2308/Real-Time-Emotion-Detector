# %%
import cv2

# %%
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From c:\Users\intel\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img = cv2.imread('happygirl.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
            predictions[0]['dominant_emotion'],
            (0,50),
            font,1,
            (0,0,255),
            2,
            cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:49<00:00, 12.32s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 2.743872480404677e-09,
#    'disgust': 9.217327752566779e-18,
#    'fear': 1.0510676983530225e-08,
#    'happy': 99.63856337300321,
#    'sad': 2.303728545350308e-06,
#    'surprise': 0.0003197144641970291,
#    'neutral': 0.3611155069539253},
#   'dominant_emotion': 'happy',
#   'region': {'x': 136,
#    'y': 73,
#    'w': 275,
#    'h': 275,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.92,
#   'age': 31,
#   'gender': {'Woman': 99.99969005584717, 'Man': 0.00031541687803837704},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 0.010801324242493138,
#    'indian': 0.0017021631720126607,
#    'black': 2.326064532098826e-05,
#    'white': 98.36867451667786,
#    'middle eastern': 0.8823622949421406,
#    'latino hispanic': 0.7364318706095219},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
predictions[0]  # Access the first element
# Out:
# {'emotion': {'angry': 2.743872480404677e-09,
#   'disgust': 9.217327752566779e-18,
#   'fear': 1.0510676983530225e-08,
#   'happy': 99.63856337300321,
#   'sad': 2.303728545350308e-06,
#   'surprise': 0.0003197144641970291,
#   'neutral': 0.3611155069539253},
#  'dominant_emotion': 'happy',
#  'region': {'x': 136,
#   'y': 73,
#   'w': 275,
#   'h': 275,
#   'left_eye': None,
#   'right_eye': None},
#  'face_confidence': 0.92,
#  'age': 31,
#  'gender': {'Woman': 99.99969005584717, 'Man': 0.00031541687803837704},
#  'dominant_gender': 'Woman',
#  'race': {'asian': 0.010801324242493138,
#   'indian': 0.0017021631720126607,
#   'black': 2.326064532098826e-05,
#   'white': 98.36867451667786,
#   'middle eastern': 0.8823622949421406,
#   'latino hispanic': 0.7364318706095219},
#  'dominant_race': 'white'}

# %%
type(predictions[0])
# Out:
# dict

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(gray,1.1,4)

for(x,y,w,h) in faces:
    cv2.rectangle(img, (x,y),(x+w,y+h),(0,255,0),2)

# %%
img2 = cv2.imread('sadimage.jpg')

# %%
plt.imshow(img2)

# %%
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %%
predictions2 = DeepFace.analyze(img2)
# Out:
# Action: race: 100%|██████████| 4/4 [00:10<00:00,  2.57s/it]

# %%
type(predictions2)
# Out:
# list

# %%
predictions2
# Out:
# [{'emotion': {'angry': 23.40753674507141,
#    'disgust': 0.048099461128003895,
#    'fear': 4.733133688569069,
#    'happy': 0.011342577636241913,
#    'sad': 54.11677956581116,
#    'surprise': 0.15508850337937474,
#    'neutral': 17.528019845485687},
#   'dominant_emotion': 'sad',
#   'region': {'x': 154,
#    'y': 82,
#    'w': 164,
#    'h': 164,
#    'left_eye': (258, 149),
#    'right_eye': (205, 144)},
#   'face_confidence': 0.9,
#   'age': 30,
#   'gender': {'Woman': 0.0006665867203992093, 'Man': 99.99933242797852},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.003796842065639794,
#    'indian': 3.608778491616249,
#    'black': 0.004760835145134479,
#    'white': 9.202039986848831,
#    'middle eastern': 82.74863362312317,
#    'latino hispanic': 4.431987553834915},
#   'dominant_race': 'middle eastern'}]

# %%
type(predictions2[0])
# Out:
# dict

# %%
predictions2[0]['dominant_emotion']
# Out:
# 'sad'

# %%
faceCascade2 = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

faces2 = faceCascade2.detectMultiScale(gray,1.1,4)

for(x,y,w,h) in faces2:
    cv2.rectangle(img2, (x,y),(x+w,y+h),(0,255,0),2)

# %%
font2 = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img2,predictions2[0]['dominant_emotion'],
            (0,50),
            font2,1,
            (0,0,255),
            2,
            cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
